# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Baca File
df = pd.read_csv("Pendaftar_Beasiswa_csv.csv", sep = ";")
df
# Out:
#        No.  Periode  Angkatan Kabupaten                    Propinsi  Semester  \
# 0        1  1012019      2017       NaN                         NaN       3.0
# 1        2  1012019      2017  Magelang                 Jawa Tengah       3.0
# 2        3  1012019      2017       NaN                         NaN       3.0
# 3        4  1012019      2017       NaN                         NaN       3.0
# 4        5  1012019      2015    Sleman  Daerah Istimewa YogYakarta       7.0
# ...    ...      ...       ...       ...                         ...       ...
# 1102  1103  1012023      2021       NaN                         NaN       3.0
# 1103  1104  1012023      2021       NaN                         NaN       3.0
# 1104  1105  1012023      2021       NaN                         NaN       3.0
# 1105  1106  1012023      2020       NaN                         NaN       5.0
# 1106  1107  1012023      2021       NaN                         NaN       3.0
#
# ...

# %%
#Drop kolom yag tidak diperlukan
df = df.drop('Kabupaten',axis=1)
df = df.drop('Propinsi', axis=1)
df = df.drop('No.', axis=1)
df = df.drop('Periode', axis=1)
# df = df.drop('Angkatan', axis=1)
df
# Out:
#       Angkatan  Semester   IPK Srt Ket. Tidak Mampu  Penghasilan Bapak  \
# 0         2017       3.0  3.87                  NaN                0.0
# 1         2017       3.0  2.79                  ada                0.0
# 2         2017       3.0  3.88                  NaN          2000000.0
# 3         2017       3.0  3.95                  NaN          2374288.0
# 4         2015       7.0  3.35                  NaN                0.0
# ...        ...       ...   ...                  ...                ...
# 1102      2021       3.0  3.08                  NaN          2000000.0
# 1103      2021       3.0  3.80                  NaN                0.0
# 1104      2021       3.0  3.50                  NaN          3187500.0
# 1105      2020       5.0  3.66                  NaN          2000000.0
# 1106      2021       3.0  3.27                  ada                0.0
#
#       Penghasilan Ibu  Tgh. Listrik  Jml. Tagunggan masih studi  Tunggakan  \
# ...

# %%
#Mengecek Missing Value
df.isnull().sum()
# Out:
# Angkatan                        0
# Semester                        0
# IPK                             0
# Srt Ket. Tidak Mampu          624
# Penghasilan Bapak               0
# Penghasilan Ibu                 1
# Tgh. Listrik                    2
# Jml. Tagunggan masih studi      2
# Tunggakan                       6
# Keadaan Orang Tua               0
# Jumlah Adik                    16
# Jumlah Kakak                   16
# Jml. Point                      2
# Status beasiswa                 0
# dtype: int64

# %%
#Mengganti NaN di kolom 'Srt Ket. Tidak Mampu' dengan tidak ada
df['Srt Ket. Tidak Mampu'] = df['Srt Ket. Tidak Mampu'].replace(np.nan, "tidak ada")
df
# Out:
#       Angkatan  Semester   IPK Srt Ket. Tidak Mampu  Penghasilan Bapak  \
# 0         2017       3.0  3.87            tidak ada                0.0
# 1         2017       3.0  2.79                  ada                0.0
# 2         2017       3.0  3.88            tidak ada          2000000.0
# 3         2017       3.0  3.95            tidak ada          2374288.0
# 4         2015       7.0  3.35            tidak ada                0.0
# ...        ...       ...   ...                  ...                ...
# 1102      2021       3.0  3.08            tidak ada          2000000.0
# 1103      2021       3.0  3.80            tidak ada                0.0
# 1104      2021       3.0  3.50            tidak ada          3187500.0
# 1105      2020       5.0  3.66            tidak ada          2000000.0
# 1106      2021       3.0  3.27                  ada                0.0
#
#       Penghasilan Ibu  Tgh. Listrik  Jml. Tagunggan masih studi  Tunggakan  \
# ...

# %%
#Drop baris yang ada NaN
df = df.dropna()

# %%
#Encode
# Check the unique values in the column to ensure they are "ada" and "tidak ada"
print(df['Srt Ket. Tidak Mampu'].unique())
# Out:
# ['tidak ada' 'ada']

# %%
# Custom mapping dictionary
mapping = {'ada': 1, 'tidak ada': 0}

# %%
# Apply the mapping to the column
df['Srt Ket. Tidak Mampu'] = df['Srt Ket. Tidak Mampu'].map(mapping)
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8884\2786683976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Srt Ket. Tidak Mampu'] = df['Srt Ket. Tidak Mampu'].map(mapping)

# %%
# Display the DataFrame with the new encoded column
print(df.head())
# Out:
#    Angkatan  Semester   IPK  Srt Ket. Tidak Mampu  Penghasilan Bapak  \
# 0      2017       3.0  3.87                     0                0.0
# 1      2017       3.0  2.79                     1                0.0
# 2      2017       3.0  3.88                     0          2000000.0
# 3      2017       3.0  3.95                     0          2374288.0
# 4      2015       7.0  3.35                     0                0.0
#
#    Penghasilan Ibu  Tgh. Listrik  Jml. Tagunggan masih studi  Tunggakan  \
# 0        1259300.0       75000.0                         2.0        0.0
# 1        1128100.0      298000.0                         1.0        0.0
# 2              0.0      118180.0                         0.0        0.0
# 3        5750000.0      433469.0                         2.0        0.0
# 4        2921800.0      100000.0                         2.0        0.0
#
#    Keadaan Orang Tua  Jumlah Adik  Jumlah Kakak  Jml. Point Status beasiswa
# ...

# %%
# Categorical columns
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['Status beasiswa']
# Numerical columns : ['Angkatan', 'Semester', 'IPK', 'Srt Ket. Tidak Mampu', 'Penghasilan Bapak', 'Penghasilan Ibu', 'Tgh. Listrik', 'Jml. Tagunggan masih studi', 'Tunggakan', 'Keadaan Orang Tua', 'Jumlah Adik', 'Jumlah Kakak', 'Jml. Point']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1106
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Angkatan                    1085 non-null   int64
#  1   Semester                    1085 non-null   float64
#  2   IPK                         1085 non-null   float64
#  3   Srt Ket. Tidak Mampu        1085 non-null   int64
#  4   Penghasilan Bapak           1085 non-null   float64
#  5   Penghasilan Ibu             1085 non-null   float64
#  6   Tgh. Listrik                1085 non-null   float64
#  7   Jml. Tagunggan masih studi  1085 non-null   float64
#  8   Tunggakan                   1085 non-null   float64
#  9   Keadaan Orang Tua           1085 non-null   int64
#  10  Jumlah Adik                 1085 non-null   float64
#  11  Jumlah Kakak                1085 non-null   float64
#  12  Jml. Point                  1085 non-null   float64
# ...

# %%
#Hapus Outlier
import matplotlib.pyplot as plt
df.plot(kind='box', subplots=True, layout=(8,8), figsize=(29,30))
plt.show()

# %%
df1 = df
df2 = df

# %%
#Penghasilan Bapak
# calculate summary statistics
mean = df['Penghasilan Bapak'].mean()
std  = df['Penghasilan Bapak'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Penghasilan Bapak'] >= lower_bound)
                & (df1['Penghasilan Bapak'] <= upper_bound)]
# Out:
# Lower Bound : -2014700.302591373
# Upper Bound : 5854850.198462341

# %%
#Penghasilan Ibu
# calculate summary statistics
mean = df['Penghasilan Ibu'].mean()
std  = df['Penghasilan Ibu'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Penghasilan Ibu'] >= lower_bound)
                & (df1['Penghasilan Ibu'] <= upper_bound)]
# Out:
# Lower Bound : -2434864.752406426
# Upper Bound : 4520746.3159455955

# %%
#Jml. Tangunggan masih studi
# calculate summary statistics
mean = df['Jml. Tagunggan masih studi'].mean()
std  = df['Jml. Tagunggan masih studi'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Jml. Tagunggan masih studi'] >= lower_bound)
                & (df1['Jml. Tagunggan masih studi'] <= upper_bound)]
# Out:
# Lower Bound : -1599590.6208760822
# Upper Bound : 1723174.1563599533

# %%
#Tunggakan
# calculate summary statistics
mean = df['Tunggakan'].mean()
std  = df['Tunggakan'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Tunggakan'] >= lower_bound)
                & (df1['Tunggakan'] <= upper_bound)]
# Out:
# Lower Bound : -7379402.847627655
# Upper Bound : 11607137.530429497

# %%
#Keadaan Orang Tua
# calculate summary statistics
mean = df['Keadaan Orang Tua'].mean()
std  = df['Keadaan Orang Tua'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Keadaan Orang Tua'] >= lower_bound)
                & (df1['Keadaan Orang Tua'] <= upper_bound)]
# Out:
# Lower Bound : -0.3794036216747707
# Upper Bound : 7.844841409693204

# %%
#Jumlah Adik
# calculate summary statistics
mean = df['Jumlah Adik'].mean()
std  = df['Jumlah Adik'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Jumlah Adik'] >= lower_bound)
                & (df1['Jumlah Adik'] <= upper_bound)]
# Out:
# Lower Bound : -1.225678192355132
# Upper Bound : 2.8090883306039798

# %%
#Jumlah Kakak
# calculate summary statistics
mean = df['Jumlah Kakak'].mean()
std  = df['Jumlah Kakak'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Jumlah Kakak'] >= lower_bound)
                & (df1['Jumlah Kakak'] <= upper_bound)]
# Out:
# Lower Bound : -1.2179685055239862
# Upper Bound : 2.799535325800484

# %%
#Jml. Point
# calculate summary statistics
mean = df['Jml. Point'].mean()
std  = df['Jml. Point'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
df2 = df1[(df1['Jml. Point'] >= lower_bound)
                & (df1['Jml. Point'] <= upper_bound)]
# Out:
# Lower Bound : -4.359407803024135
# Upper Bound : 6.383370936664688

# %%
#Outlier baru
import matplotlib.pyplot as plt
df2.plot(kind='box', subplots=True, layout=(8,8), figsize=(29,30))
plt.show()

# %%
#Data Balancing
df2.groupby('Status beasiswa').size()
# Out:
# Status beasiswa
# T    564
# Y    460
# dtype: int64

# %%
data_1 = df2[df2['Status beasiswa'] == 'T']
data_2 = df2[df2['Status beasiswa'] == 'Y']

# %%
from sklearn.utils import resample

data_1_resample = resample(data_1, n_samples=450, random_state=0, replace=True)
data_2_resample = resample(data_2, n_samples=450, random_state=0, replace=True)

# %%
df2 = pd.concat([data_1_resample, data_2_resample])

# %%
# Count the occurrences of each value in the 'Status beasiswa' column
status_counts = df2['Status beasiswa'].value_counts()

# %%
# Create a bar plot
plt.figure(figsize=(10, 8))
status_counts.plot(kind='bar', color=['blue', 'magenta'])

# Set the title and labels
plt.title('Status Beasiswa Distribution')
plt.xlabel('Status Beasiswa')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Ensure labels are horizontal
plt.show()

# %%
#Normalisasi
X = df2[['Angkatan','Semester', 'IPK', 'Srt Ket. Tidak Mampu', 'Penghasilan Bapak', 'Penghasilan Ibu', 'Tgh. Listrik', 'Jml. Tagunggan masih studi', 'Tunggakan', 'Keadaan Orang Tua', 'Jumlah Adik', 'Jumlah Kakak', 'Jml. Point']]
Y = df2[['Status beasiswa']]

# %%
from sklearn.preprocessing import MinMaxScaler

# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Numerical columns
num_col_ = [col for col in X.columns if X[col].dtype != 'object']
x1 = X
# learning the statistical parameters for each of the data and transforming
x1[num_col_] = scaler.fit_transform(x1[num_col_])
x1.head()
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8884\1402675863.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1[num_col_] = scaler.fit_transform(x1[num_col_])
#       Angkatan  Semester       IPK  Srt Ket. Tidak Mampu  Penghasilan Bapak  \
# 1101  0.833333       0.5  0.638462                   1.0           0.172077
# 305   0.333333       0.0  0.623077                   0.0           0.129058
# 677   0.666667       0.0  1.000000                   1.0           0.412796
# 16    0.333333       0.0  0.438462                   0.0           0.164847
# 527   0.666667       0.0  0.692308                   0.0           0.134954
#
#       Penghasilan Ibu  Tgh. Listrik  Jml. Tagunggan masih studi  Tunggakan  \
# ...

# %%
#Split Data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score

# %%
from sklearn.svm import SVC
linear_svc = SVC(max_iter=1000)
linear_svc.fit(X_train,Y_train)
Y_pred = linear_svc.predict(X_test)
accuracy_svc=round(accuracy_score(Y_test,Y_pred)* 100, 2)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
# Out:
# C:\Users\sasha\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm = confusion_matrix(Y_test, Y_pred)
accuracy = accuracy_score(Y_test,Y_pred)
precision =precision_score(Y_test, Y_pred,average='micro')
recall =  recall_score(Y_test, Y_pred,average='micro')
f1 = f1_score(Y_test,Y_pred,average='micro')
print('Confusion matrix for SVM\n',cm)
print('accuracy_SVM: %.3f' %accuracy)
print('precision_RandomForest: %.3f' %precision)
print('recall_RandomForest: %.3f' %recall)
print('f1-score_RandomForest : %.3f' %f1)
# Out:
# Confusion matrix for SVM
#  [[106  27]
#  [ 38  99]]
# accuracy_SVM: 0.759
# precision_RandomForest: 0.759
# recall_RandomForest: 0.759
# f1-score_RandomForest : 0.759

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_prediction = random_forest.predict(X_test)
accuracy_rf=round(accuracy_score(Y_test,Y_prediction)* 100, 2)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8884\1509343683.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest.fit(X_train, Y_train)

# %%
cm = confusion_matrix(Y_test, Y_prediction)
accuracy = accuracy_score(Y_test,Y_prediction)
precision =precision_score(Y_test, Y_prediction,average='micro')
recall =  recall_score(Y_test, Y_prediction,average='micro')
f1 = f1_score(Y_test,Y_prediction,average='micro')
print('Confusion matrix for DecisionTree\n',cm)
print('accuracy_DecisionTree: %.3f' %accuracy)
print('precision_DecisionTree: %.3f' %precision)
print('recall_DecisionTree: %.3f' %recall)
print('f1-score_DecisionTree : %.3f' %f1)
# Out:
# Confusion matrix for DecisionTree
#  [[122  11]
#  [ 18 119]]
# accuracy_DecisionTree: 0.893
# precision_DecisionTree: 0.893
# recall_DecisionTree: 0.893
# f1-score_DecisionTree : 0.893

# %%
#Tabel perbandingan
results = pd.DataFrame({
    'Model': [ 'Random Forest',
              'Support Vector Machine'],
    'Score': [ acc_random_forest,
              acc_linear_svc],
    "Accuracy_score":[accuracy_rf,
                      accuracy_svc
                     ]})
result_df = results.sort_values(by='Accuracy_score', ascending=False)
result_df = result_df.reset_index(drop=True)
result_df.head(9)

#Visualisasi perbandingan
plt.subplots(figsize=(12,8))
ax=sns.barplot(x='Model',y="Accuracy_score",data=result_df)
labels = (result_df["Accuracy_score"])
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+1, str(v), horizontalalignment = 'center', size = 15, color = 'black')

ax.set_title("Komparasi Model pada Split Data 70:30", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Komparasi Model pada Split Data 70:30')

# %%
#Split Data 80:20

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.svm import SVC
linear_svc = SVC(max_iter=1000)
linear_svc.fit(X_train,Y_train)
Y_pred = linear_svc.predict(X_test)
accuracy_svc=round(accuracy_score(Y_test,Y_pred)* 100, 2)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
# Out:
# C:\Users\sasha\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cm = confusion_matrix(Y_test, Y_pred)
accuracy = accuracy_score(Y_test,Y_pred)
precision =precision_score(Y_test, Y_pred,average='micro')
recall =  recall_score(Y_test, Y_pred,average='micro')
f1 = f1_score(Y_test,Y_pred,average='micro')
print('Confusion matrix for SVM\n',cm)
print('accuracy_SVM: %.3f' %accuracy)
print('precision_RandomForest: %.3f' %precision)
print('recall_RandomForest: %.3f' %recall)
print('f1-score_RandomForest : %.3f' %f1)
# Out:
# Confusion matrix for SVM
#  [[66 17]
#  [27 70]]
# accuracy_SVM: 0.756
# precision_RandomForest: 0.756
# recall_RandomForest: 0.756
# f1-score_RandomForest : 0.756

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_prediction = random_forest.predict(X_test)
accuracy_rf=round(accuracy_score(Y_test,Y_prediction)* 100, 2)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
# Out:
# C:\Users\sasha\AppData\Local\Temp\ipykernel_8884\1509343683.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest.fit(X_train, Y_train)

# %%
cm = confusion_matrix(Y_test, Y_prediction)
accuracy = accuracy_score(Y_test,Y_prediction)
precision =precision_score(Y_test, Y_prediction,average='micro')
recall =  recall_score(Y_test, Y_prediction,average='micro')
f1 = f1_score(Y_test,Y_prediction,average='micro')
print('Confusion matrix for DecisionTree\n',cm)
print('accuracy_DecisionTree: %.3f' %accuracy)
print('precision_DecisionTree: %.3f' %precision)
print('recall_DecisionTree: %.3f' %recall)
print('f1-score_DecisionTree : %.3f' %f1)
# Out:
# Confusion matrix for DecisionTree
#  [[79  4]
#  [12 85]]
# accuracy_DecisionTree: 0.911
# precision_DecisionTree: 0.911
# recall_DecisionTree: 0.911
# f1-score_DecisionTree : 0.911

# %%
#Tabel perbandingan
results = pd.DataFrame({
    'Model': [ 'Random Forest',
              'Support Vector Machine'],
    'Score': [ acc_random_forest,
              acc_linear_svc],
    "Accuracy_score":[accuracy_rf,
                      accuracy_svc
                     ]})
result_df = results.sort_values(by='Accuracy_score', ascending=False)
result_df = result_df.reset_index(drop=True)
result_df.head(9)

#Visualisasi perbandingan
plt.subplots(figsize=(12,8))
ax=sns.barplot(x='Model',y="Accuracy_score",data=result_df)
labels = (result_df["Accuracy_score"])
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+1, str(v), horizontalalignment = 'center', size = 15, color = 'black')

ax.set_title("Komparasi Model pada Split Data 80:20", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Komparasi Model pada Split Data 80:20')
